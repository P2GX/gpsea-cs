# %% [markdown]
# # Loeys-Dietz syndrome 3 and 6
# Loeys-Dietz syndrome (LDS) is an autosomal dominant aortic aneurysm syndrome characterized by multisystemic involvement. The most typical clinical triad includes hypertelorism, bifid uvula or cleft palate and aortic aneurysm with tortuosity. Affected individuals may expereince aortic dissection at smaller aortic diameter and arterial aneurysms throughout the arterial tree. The genetic cause is heterogeneous and includes mutations in genes encoding for components of the transforming growth factor beta (TGFβ) signalling pathway: TGFBR1, TGFBR2, SMAD2, SMAD3, TGFB2 and TGFB3 (See [Velchev JD, et al. (2021). Loeys-Dietz Syndrome. Adv Exp Med Biol](https://pubmed.ncbi.nlm.nih.gov/34807423/)).
#
# This notebook will explore whether there are significant differences in phenotypic features between LDS3 (SMAD3) and LDS6 (SMAD2)

# %%
import gpsea
import hpotk

store = hpotk.configure_ontology_store()
hpo = store.load_minimal_hpo()
print(f'Loaded HPO v{hpo.version}')
print(f"Using genophenocorr version {gpsea.__version__}")
# Out:
# Loaded HPO v2025-01-16
# Using genophenocorr version 0.9.6.dev0

# %% [markdown]
# # LDS3
# [Loeys-Dietz syndrome-3 (LDS3)](https://omim.org/entry/613795) is caused by heterozygous mutation in the SMAD3 gene.

# %%
from ppktstore.registry import configure_phenopacket_registry

smad3_symbol = 'SMAD3'
smad3_mane_tx_id = 'NM_005902.4'
smad3_mane_protein_id = 'NP_005893.1' # mothers against decapentaplegic homolog 3
lds3_disease_id = "OMIM:613795"

phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.24") as ps:
    lds3_phenopackets = tuple(ps.iter_cohort_phenopackets(smad3_symbol))

print(f"{len(lds3_phenopackets)} LDS3 phenopackets")
# Out:
# 49 LDS3 phenopackets

# %% [markdown]
# # LDS6
# [Loeys-Dietz syndrome-6 (LDS6)](https://omim.org/entry/619656) is caused by heterozygous mutation in the SMAD2 gene

# %%
smad2_symbol = 'SMAD2'
smad2_mane_tx_id = 'NM_005901.6'
smad2_mane_protein_id = 'NP_005892.1' # mothers against decapentaplegic homolog 2 isoform 1

lds6_disease_id = "OMIM:619656"

phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.24") as ps:
    lds6_phenopackets = tuple(ps.iter_cohort_phenopackets(smad2_symbol))

print(f"{len(lds6_phenopackets)} LDS6 phenopackets")
# Out:
# 23 LDS6 phenopackets

# %%
from gpsea.preprocessing import configure_caching_cohort_creator, load_phenopackets

lds3_and_lds6_phenopackets = list()
lds3_and_lds6_phenopackets.extend(lds3_phenopackets)
lds3_and_lds6_phenopackets.extend(lds6_phenopackets)
print(f"Got {len(lds3_and_lds6_phenopackets)} LDS3 and LDS6 phenopackets")

cohort_creator = configure_caching_cohort_creator(hpo)
cohort, validation = load_phenopackets(
    phenopackets=lds3_and_lds6_phenopackets, 
    cohort_creator=cohort_creator,
)

validation.summarize()
# Out:
# Got 72 LDS3 and LDS6 phenopackets
# Individuals Processed: 100%|██████████| 72/72 [00:00<00:00, 249.38 individuals/s]
# Validated under permissive policy
# No errors or warnings were found

# %%
from gpsea.analysis.pcats import configure_hpo_term_analysis
from gpsea.analysis.clf import prepare_classifiers_for_terms_of_interest

analysis = configure_hpo_term_analysis(hpo)

pheno_clfs = prepare_classifiers_for_terms_of_interest(
    cohort=cohort,
    hpo=hpo,
)

# %%
from gpsea.analysis.clf import diagnosis_classifier
from gpsea.view import MtcStatsViewer

lds_3_6_disease_clf = diagnosis_classifier (
    diagnoses=(lds3_disease_id, lds6_disease_id),
    labels=('LDS3', 'LDS6'),
)

lds_3_6_result = analysis.compare_genotype_vs_phenotypes(
    cohort=cohort,
    gt_clf=lds_3_6_disease_clf,
    pheno_clfs=pheno_clfs,
)

viewer = MtcStatsViewer()
viewer.process(lds_3_6_result)
# Out:
# <div>
#     <style>
#         /** Light theme is the default */
#         :root {
#             --gpsea-color-text: black;
#             --gpsea-color-link-text: rgb(0, 118, 187);
#             --gpsea-color-link-hover: rgb(0, 99, 156);
#             --gpsea-color-primary-a0: #2f5170;
#             --gpsea-color-primary-a10: #4778a5;
#             --gpsea-color-primary-a20: #5995ce;
#             --gpsea-color-primary-a60: LightSkyBlue;
#             --gpsea-color-surface-a0: #fcfcfc;
#             --gpsea-color-surface-a10: #ffffff;
#             --gpsea-color-surface-a20: #b3b3b3;
#             --gpsea-color-surface-a30: #8d8d8d;
#             --gpsea-color-surface-a40: #646464;
#             --gpsea-color-surface-a50: #000000;
#         }
#
#         /** Dark theme */
#         /*
#         @media (prefers-color-scheme: dark) {
#             :root {
#                 --gpsea-color-text: rgb(240, 240, 240);
#                 --gpsea-color-link-text: rgb(240, 240, 240);
#                 --gpsea-color-link-hover: lightblue;
#                 --gpsea-color-primary-a0: #64a3df;
#                 --gpsea-color-primary-a10: #5286b8;
#                 --gpsea-color-primary-a20: #375c7e;
#                 --gpsea-color-primary-a60: #233b52;
#                 --gpsea-color-surface-a0: #121212;
#                 --gpsea-color-surface-a10: #282828;
#                 --gpsea-color-surface-a20: #3f3f3f;
#                 --gpsea-color-surface-a30: #575757;
#                 --gpsea-color-surface-a40: #717171;
#                 --gpsea-color-surface-a50: #8b8b8b;
#             }
#         }
#         */
#
#         #gpsea-body {
#             max-width: 1600px;
#             color: var(--gpsea-color-text);
#             background-color: var(--gpsea-color-surface-a0);
#             padding: 10px 0;
#         }
#
#         #gpsea-body {
#
#             h1,
#             h2,
#             h3,
#             h4,
#             h5 {
#                 color: var(--gpsea-color-primary-a0);
#             }
#
#             a {
#                 color: var(--gpsea-color-link-text);
#                 text-decoration: none;
#             }
#
#             a:hover {
#                 color: var(--gpsea-color-link-hover);
#             }
#
#             #cohort-summary {
#                 max-width: 800px;
#             }
#
#             td {
#                 padding: 5px 0;
#             }
#
#             .cards {
#                 display: flex;
#                 flex-flow: row wrap;
#                 align-items: top;
#                 gap: 1rem;
#             }
#
#             .card {
#                 border-radius: 5px;
#                 padding: 0px 10px;
#                 background: var(--gpsea-color-surface-a10);
#                 border: 1px solid var(--gpsea-color-surface-a30);
#                 box-shadow: 0 4px 8px var(--gpsea-color-surface-a30);
#             }
#
#             table {
#                 width: 100%;
#                 border-collapse: collapse;
#                 margin: 10px 0;
#                 font-size: 0.9em;
#                 font-family: sans-serif;
#                 box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#                 border: 1px solid var(--gpsea-color-primary-a60);
#             }
#
#             th {
#                 text-align: left;
#                 padding: 2px;
#                 font-weight: bold;
#                 font-size: 120%;
#                 color: var(--gpsea-color-text);
#                 background-color: var(--gpsea-color-primary-a60);
#             }
#
#             table td,
#             tr {
#                 text-align: left;
#                 padding: 0px 5px;
#             }
#
#             tr:nth-child(even) {
#                 background-color: var(--gpsea-color-surface-a10);
#             }
#
#             tr:nth-child(odd) {
#                 background-color: var(--gpsea-color-surface-a20);
#             }
#
#             caption {
#                 caption-side: top;
#                 text-align: left;
#                 padding-bottom: 10px;
#                 font-weight: bold;
#             }
#         }
#     </style>
#     <div id="gpsea-body">
#
# <h1>Phenotype testing report</h1>
# <div class="cards">
#   <div class="card">
#     <ul>
#       <li>Phenotype MTC filter: <em>Independent filtering HPO filter</em></li>
#       <li>Multiple testing correction: <em>fdr_bh</em></li>
#     </ul>
#   </div>
#   <div class="card">
#     <table>
#       <tbody>
#         <tr>
#           <th>Reason</th>
#           <th>Count</th>
#         </tr>
#
#         <tr>
#
#             <td><a href="https://P2GX.github.io/gpsea/stable/user-guide/analyses/mtc.html#skip-terms-if-all-counts-are-identical-to-counts-for-a-child-term">Skip terms if all counts are identical to counts for a child term</a></td>
#
#           <td>2</td>
#         </tr>
#
#         <tr>
#
#             <td><a href="https://P2GX.github.io/gpsea/stable/user-guide/analyses/mtc.html#skipping-general-level-terms">Skipping "general" level terms</a></td>
#
#           <td>71</td>
#         </tr>
#
#         <tr>
#
#             <td><a href="https://P2GX.github.io/gpsea/stable/user-guide/analyses/mtc.html#skipping-terms-that-are-rare-on-the-cohort-level">Skipping terms that are rare on the cohort level (in less than 40% of the cohort members)</a></td>
#
#           <td>211</td>
#         </tr>
#
#       </tbody>
#       <caption>
#         Performed statistical tests for 25 out of the total of 309 HPO terms.
#       </caption>
#     </table>
#   </div>
# </div>
#
#     </div>
# </div>

# %%
from gpsea.view import summarize_hpo_analysis
summarize_hpo_analysis(hpo=hpo, result=lds_3_6_result)
# Out:
# Diagnosis                                            OMIM:613795  \
# Thoracic aortic aneurysm [HP:0012727]                  0/22 (0%)
# Aortic aneurysm [HP:0004942]                         26/48 (54%)
# Bifid uvula [HP:0000193]                             13/38 (34%)
# Soft skin [HP:0000977]                               23/37 (62%)
# Varicose veins [HP:0002619]                          14/22 (64%)
# High palate [HP:0000218]                             12/20 (60%)
# Abdominal aortic aneurysm [HP:0005112]                 0/22 (0%)
# Inguinal hernia [HP:0000023]                         12/39 (31%)
# Umbilical hernia [HP:0001537]                        12/39 (31%)
# Hypertelorism [HP:0000316]                           13/35 (37%)
# Joint hypermobility [HP:0001382]                     12/36 (33%)
# Spontaneous pneumothorax [HP:0002108]                 2/20 (10%)
# Scoliosis [HP:0002650]                               20/43 (47%)
# Abnormal palate morphology [HP:0000174]             24/24 (100%)
# Abnormal oral cavity morphology [HP:0000163]        24/24 (100%)
# Vascular dilatation [HP:0002617]                    26/26 (100%)
# Abnormal aortic morphology [HP:0001679]             26/26 (100%)
# Abnormal morphology of the great vessels [HP:00...  26/26 (100%)
# Osteoarthritis [HP:0002758]                          26/38 (68%)
# Abnormal systemic arterial morphology [HP:0011004]  29/29 (100%)
# Abnormality of the vertebral column [HP:0000925]    31/31 (100%)
# Abnormal blood vessel morphology [HP:0033353]       32/32 (100%)
# Abnormal axial skeleton morphology [HP:0009121]     33/33 (100%)
# Abnormal sternum morphology [HP:0000766]              6/20 (30%)
# Arachnodactyly [HP:0001166]                           7/18 (39%)
#
# Diagnosis                                            OMIM:619656  \
# Thoracic aortic aneurysm [HP:0012727]                10/16 (62%)
# Aortic aneurysm [HP:0004942]                        10/10 (100%)
# Bifid uvula [HP:0000193]                               1/14 (7%)
# Soft skin [HP:0000977]                                 1/5 (20%)
# Varicose veins [HP:0002619]                           4/12 (33%)
# High palate [HP:0000218]                              5/15 (33%)
# Abdominal aortic aneurysm [HP:0005112]                 1/11 (9%)
# Inguinal hernia [HP:0000023]                          5/11 (45%)
# Umbilical hernia [HP:0001537]                          2/4 (50%)
# Hypertelorism [HP:0000316]                            4/14 (29%)
# Joint hypermobility [HP:0001382]                       2/6 (33%)
# Spontaneous pneumothorax [HP:0002108]                   0/9 (0%)
# Scoliosis [HP:0002650]                                7/14 (50%)
# Abnormal palate morphology [HP:0000174]               7/7 (100%)
# Abnormal oral cavity morphology [HP:0000163]          7/7 (100%)
# Vascular dilatation [HP:0002617]                    11/11 (100%)
# Abnormal aortic morphology [HP:0001679]             12/12 (100%)
# Abnormal morphology of the great vessels [HP:00...  12/12 (100%)
# Osteoarthritis [HP:0002758]                           2/2 (100%)
# Abnormal systemic arterial morphology [HP:0011004]  16/16 (100%)
# Abnormality of the vertebral column [HP:0000925]    10/10 (100%)
# Abnormal blood vessel morphology [HP:0033353]       17/17 (100%)
# Abnormal axial skeleton morphology [HP:0009121]     11/11 (100%)
# Abnormal sternum morphology [HP:0000766]              5/15 (33%)
# Arachnodactyly [HP:0001166]                           6/14 (43%)
#
# Diagnosis                                           Corrected p values  \
# Thoracic aortic aneurysm [HP:0012727]                         0.000423
# Aortic aneurysm [HP:0004942]                                  0.113597
# Bifid uvula [HP:0000193]                                      0.650869
# Soft skin [HP:0000977]                                        0.731597
# Varicose veins [HP:0002619]                                   0.731597
# High palate [HP:0000218]                                      0.731597
# Abdominal aortic aneurysm [HP:0005112]                        1.000000
# Inguinal hernia [HP:0000023]                                  1.000000
# Umbilical hernia [HP:0001537]                                 1.000000
# Hypertelorism [HP:0000316]                                    1.000000
# Joint hypermobility [HP:0001382]                              1.000000
# Spontaneous pneumothorax [HP:0002108]                         1.000000
# Scoliosis [HP:0002650]                                        1.000000
# Abnormal palate morphology [HP:0000174]                       1.000000
# Abnormal oral cavity morphology [HP:0000163]                  1.000000
# Vascular dilatation [HP:0002617]                              1.000000
# Abnormal aortic morphology [HP:0001679]                       1.000000
# Abnormal morphology of the great vessels [HP:00...            1.000000
# Osteoarthritis [HP:0002758]                                   1.000000
# Abnormal systemic arterial morphology [HP:0011004]            1.000000
# Abnormality of the vertebral column [HP:0000925]              1.000000
# Abnormal blood vessel morphology [HP:0033353]                 1.000000
# Abnormal axial skeleton morphology [HP:0009121]               1.000000
# Abnormal sternum morphology [HP:0000766]                      1.000000
# Arachnodactyly [HP:0001166]                                   1.000000
#
# Diagnosis                                           p values
# Thoracic aortic aneurysm [HP:0012727]               0.000017
# Aortic aneurysm [HP:0004942]                        0.009088
# Bifid uvula [HP:0000193]                            0.078104
# Soft skin [HP:0000977]                              0.146370
# Varicose veins [HP:0002619]                         0.151415
# High palate [HP:0000218]                            0.175583
# Abdominal aortic aneurysm [HP:0005112]              0.333333
# Inguinal hernia [HP:0000023]                        0.475054
# Umbilical hernia [HP:0001537]                       0.585479
# Hypertelorism [HP:0000316]                          0.742960
# Joint hypermobility [HP:0001382]                    1.000000
# Spontaneous pneumothorax [HP:0002108]               1.000000
# Scoliosis [HP:0002650]                              1.000000
# Abnormal palate morphology [HP:0000174]             1.000000
# Abnormal oral cavity morphology [HP:0000163]        1.000000
# Vascular dilatation [HP:0002617]                    1.000000
# Abnormal aortic morphology [HP:0001679]             1.000000
# Abnormal morphology of the great vessels [HP:00...  1.000000
# Osteoarthritis [HP:0002758]                         1.000000
# Abnormal systemic arterial morphology [HP:0011004]  1.000000
# Abnormality of the vertebral column [HP:0000925]    1.000000
# Abnormal blood vessel morphology [HP:0033353]       1.000000
# Abnormal axial skeleton morphology [HP:0009121]     1.000000
# Abnormal sternum morphology [HP:0000766]            1.000000
# Arachnodactyly [HP:0001166]                         1.000000

# %%
from gpseacs.report import GpseaAnalysisReport, GPAnalysisResultSummary

f_results = (
  GPAnalysisResultSummary.from_multi( result=lds_3_6_result,  ),
)


caption = """."""
report = GpseaAnalysisReport(name="LDS 3 and 6", 
                             cohort=cohort, 
                             fet_results=f_results,
                             gene_symbol="n/a",
                             mane_tx_id="n/a",
                             mane_protein_id="n/a",
                             caption=caption)

# %%
from gpseacs.report import GpseaNotebookSummarizer
summarizer = GpseaNotebookSummarizer(hpo=hpo, gpsea_version=gpsea.__version__)
summarizer.summarize_report(report=report)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#     <style>
#     table {
#       border-collapse: collapse;
#       margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#     }
#
#     .table .column-1 {
#       text-align: left;
#     }
#     th {
#       background-color: LightSkyBlue;
#       border: 1px solid #dddddd;
#       text-align: left;
#       padding: 2px;
#       font-weight: bold;
#       font-size: 120%;
#       min-width: 100px;
#       border: 1px solid #ddd;
#       padding: 8px;
#
#     }
#
#     tr {
#       border: 1px solid #dddddd;
#     }
#
#     td {
#       padding: 2px;
#       font-weight: bold;
#     }
#
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#
#     .table td, tr {
#       text-align: right;
#     }
#
#     .lft {
#       text-align: left;
#     }
#
#     div {
#       display: block;
#       width: 100%;
#       padding-right: 1%;
#       margin-bottom: 20px; /* Add margin to separate divs */
#     }
#
#     p {
#       width: 75%;
#     }
#
#     caption {
#       caption-side: top;
#       text-align: left;
#       padding-bottom: 10px;
#       font-weight: bold;
#     }
#   </style>
# </head>
#
# <body>
#   <h1>LDS 3 and 6 Summary</h1>
#   <p>The cohort comprised 72 individuals (35 females, 35 males, 2 with unknown sex). A total of 98 HPO terms were used to annotate the cohort. Disease diagnoses: Loeys-Dietz syndrome 3 (OMIM:613795) (49 individuals), Loeys-Dietz syndrome 6 (OMIM:619656) (18 individuals), Congenital heart defects, multiple types, 8, with or without heterotaxy (OMIM:619657) (5 individuals). . A total of 25 unique variant alleles were found in n/a (transcript: n/a, protein id: n/a). HPO version: 2025-01-16. GPSEA version: 0.9.6.dev0.</p>
#
#
#
#     <table>
#       <caption style="color: black;">
#           Fisher Exact Test performed to compare HPO annotation frequency with respect to OMIM:613795 and OMIM:619656. Total of
#           25 tests were performed.
#       </caption>
#           <tbody>
#               <tr class="strng">
#                   <th>HPO Term</th>
#                   <th>OMIM:613795</th>
#                   <th>OMIM:619656</th>
#                   <th>p-val</th>
#                   <th>adj. p-val</th>
#               </tr>
#
#               <tr>
#                   <td class="lft">Thoracic aortic aneurysm [HP:0012727]</td>
#                   <td class="lft">0/22 (0%)</td>
#                   <td class="lft">10/16 (62%)</td>
#                   <td class="lft">1.69e-05</td>
#                   <td class="lft">4.23e-04</td>
#               </tr>
#
#             </tbody>
#       </table>
#
#
#
#
#
#
#
#
#
#
# </body>
# </html>

# %%
summarizer.process_latex(report=report)
# Out:
# Output to ../../supplement/tex/LDS_3_and_6_summary_draft.tex
