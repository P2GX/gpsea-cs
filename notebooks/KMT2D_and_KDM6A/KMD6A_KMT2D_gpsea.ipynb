# %% [markdown]
# # Kabuki 1 & Kabuki 2 Syndrome
#
# ##### **Kabuki 1 Syndrome** - [OMIM:147920](https://omim.org/entry/147920), MONDO:0007843
# - LYSINE-SPECIFIC METHYLTRANSFERASE 2D; **KMT2D** ([OMIM:602113](https://omim.org/entry/602113))
#
# ##### **Kabuki 2 Syndrome** - [OMIM:300867](https://www.omim.org/entry/300867), MONDO:0010465
# - LYSINE DEMETHYLASE 6A; **KDM6A** ([OMIM:300128](https://www.omim.org/entry/300128))
#
# #### **Genotype Phenotype Correlations**
#
# ##### KMT2D & KDM6A
#
# - [Banka et al (2012)](https://pubmed.ncbi.nlm.nih.gov/22126750/):
#     - analyzed the KMT2D gene in a cohort of 116 patients with Kabuki syndrome, including 18 patients previously reported by Hannibal et al. (2011), and identified KMT2D variants in 74 (63.8%).
#     - KABUK1 patients were more likely to have feeding problems, kidney anomalies, early breast bud development, joint dislocations, and palatal malformations in comparison with KMT2D mutation-negative patients
#     - **Systematic Kabuki syndrome facial morphology study suggested that nearly all patients with typical Kabuki syndrome facial features have pathogenic KMT2D mutations, although the disorder can be phenotypically variable.**
#
# - [Miyake et al (2013)](https://pubmed.ncbi.nlm.nih.gov/23913813/)
#     - screened 81 patients with Kabuki syndrome for mutations in the MLL2 and KDM6A genes and identified MLL2 mutations in 50 (61.7%) and KDM6A mutations in 5 (6.2%)
#     - Patients with **KMT2D truncating mutations (70%) had facies that were more typical of those seen in the patients originally reported with Kabuki syndrome.** High-arched eyebrows, short fifth fingers, and infantile hypotonia were more commonly seen in patients with MLL2 mutations than in those with KDM6A mutations.
#     - **Only half of the patients with KMT2D mutations had short stature and postnatal growth retardation**, compared to all of the patients with KDM6A mutations.

# %%
cohort_name_1 = 'KMT2D'
mane_tx_id_1 = 'NM_003482.4'
mane_px_id_1 = 'NP_003473.3' 

cohort_name_2 = 'KDM6A'
mane_tx_id_2 = 'NM_001291415.2'
mane_px_id_2 = 'NP_001278344.1'

# %%
import hpotk
store = hpotk.configure_ontology_store()
hpo = store.load_minimal_hpo()

# %%
from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store('0.1.20') as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(cohort_name_1))

# %%
from gpsea.preprocessing import configure_caching_cohort_creator, load_phenopackets
cohort_creator = configure_caching_cohort_creator(hpo)
cohort_1, validation = load_phenopackets(
    phenopackets=phenopackets,
    cohort_creator=cohort_creator,
)
# Out:
# Individuals Processed: 100%|██████████| 65/65 [00:00<00:00, 224.95individuals/s]

# %%
from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store('0.1.20') as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(cohort_name_2))

# %%
from gpsea.preprocessing import configure_caching_cohort_creator, load_phenopackets
cohort_creator = configure_caching_cohort_creator(hpo)
cohort_2, validation = load_phenopackets(
    phenopackets=phenopackets,
    cohort_creator=cohort_creator,
)
# Out:
# Individuals Processed: 100%|██████████| 81/81 [00:12<00:00,  6.54individuals/s]

# %%
validation.summarize()
# Out:
# Validated under none policy
# No errors or warnings were found

# %% [markdown]
# ## **Kabuki 1 Cohort**

# %%
from IPython.display import HTML, display

from gpsea.view import CohortViewable
viewer = CohortViewable(hpo)
report = viewer.process(cohort=cohort_1, transcript_id=mane_tx_id_1)
display(HTML(report))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#     <style>
#     table {
#       border-collapse: collapse;
#       margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#     }
#
#     .table .column-1 {
#       text-align: left;
#     }
#     th {
#       background-color: LightSkyBlue;
#       border: 1px solid #dddddd;
#       text-align: left;
#       padding: 2px;
#       font-weight: bold;
#       font-size: 120%;
#     }
#
#     tr {
#       border: 1px solid #dddddd;
#     }
#
#     td {
#       padding: 2px;
#       font-weight: bold;
#     }
#
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#
#     .table td, tr {
#       text-align: right;
#     }
#
#     .lft {
#       text-align: left;
#     }
#
#     div {
#       display: block;
#       width: 100%;
#       padding-right: 1%;
#       margin-bottom: 20px; /* Add margin to separate divs */
#     }
#
#     caption {
#       caption-side: top;
#       text-align: left;
#       padding-bottom: 10px;
#       font-weight: bold;
#     }
#   </style>
# </head>
#
# <body>
#   <h1>GPSEA cohort analysis</h1>
#   <p>Successfully loaded 65 individuals.</p>
#
#   <p>No errors encountered.</p>
#
#
#     <table>
#     <caption style="color: black;">
#         <h3>Top 10 HPO Terms</h3>
#         A total of 238 HPO terms were used to annotated the cohort.
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">HPO Term</th>
#                 <th>ID</th>
#                 <th>Seen in <em>n</em> individuals</th>
#             </tr>
#
#             <tr>
#                 <td class="lft">Depressed nasal tip</td>
#                 <td>HP:0000437</td>
#                 <td>36</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Prominent fingertip pads</td>
#                 <td>HP:0001212</td>
#                 <td>30</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Global developmental delay</td>
#                 <td>HP:0001263</td>
#                 <td>30</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Long palpebral fissure</td>
#                 <td>HP:0000637</td>
#                 <td>25</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Macrotia</td>
#                 <td>HP:0000400</td>
#                 <td>24</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Highly arched eyebrow</td>
#                 <td>HP:0002553</td>
#                 <td>22</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Intellectual disability</td>
#                 <td>HP:0001249</td>
#                 <td>21</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Eversion of lateral third of lower eyelids</td>
#                 <td>HP:0007655</td>
#                 <td>18</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Cleft palate</td>
#                 <td>HP:0000175</td>
#                 <td>17</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Hearing impairment</td>
#                 <td>HP:0000365</td>
#                 <td>16</td>
#                 </tr>
#
#                 </tbody>
#     </table>
#
#     <table>
#     <caption style="color: black;">
#         <h3>Top 10 Variants</h3>
#         Variants are shown according to NM_003482.4. A total of 65 unique variants were identified in the cohort.
#     </caption>
#             <tbody>
#                 <tr class="strng">
#                     <th>Count</th>
#                     <th class="lft">Variant key</th>
#                     <th>Variant Name</th>
#                     <th>Protein Variant</th>
#                     <th>Variant Class</th>
#                 </tr>
#
#                 <tr>
#                     <td>4</td>
#                     <td class="lft">12_49022655_49022655_C_T</td>
#                     <td>c.16273G>A</td>
#                     <td>p.Glu5425Lys</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>4</td>
#                     <td class="lft">12_49034182_49034182_A_G</td>
#                     <td>c.10625T>C</td>
#                     <td>p.Leu3542Pro</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">12_49033960_49033960_C_T</td>
#                     <td>c.10745G>A</td>
#                     <td>p.Arg3582Gln</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">12_49034082_49034082_C_G</td>
#                     <td>c.10725G>C</td>
#                     <td>p.Gln3575His</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">12_49034225_49034225_G_C</td>
#                     <td>c.10582C>G</td>
#                     <td>p.Leu3528Val</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>2</td>
#                     <td class="lft">12_49022634_49022634_G_A</td>
#                     <td>c.16294C>T</td>
#                     <td>p.Arg5432Trp</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>1</td>
#                     <td class="lft">12_49032140_49032140_C_A</td>
#                     <td>c.12565G>T</td>
#                     <td>p.Gly4189Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#                 <tr>
#                     <td>1</td>
#                     <td class="lft">12_49033961_49033961_G_A</td>
#                     <td>c.10744C>T</td>
#                     <td>p.Arg3582Trp</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>1</td>
#                     <td class="lft">12_49055320_49055320_T_C</td>
#                     <td>c.5A>G</td>
#                     <td>p.Asp2Gly</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>1</td>
#                     <td class="lft">12_49039557_49039557_C_A</td>
#                     <td>c.8107G>T</td>
#                     <td>p.Glu2703Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#             </tbody>
#         </table>
#     <table>
#     <caption style="color: black;">
#         <h3>Diseases</h3>
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">Disease Name</th>
#                 <th >Disease ID</th>
#                 <th>Annotation Count</th>
#               </tr>
#
#               <tr>
#                 <td class="lft">Kabuki Syndrome 1</td>
#                 <td>OMIM:147920</td>
#                 <td>65</td>
#                 </tr>
#
#            </tbody>
#     </table>
#
#     <table>
#     <caption style="color: black;">
#         <h3>Variant categories for NM_003482.4</h3>
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">Variant effect</th>
#                 <th>Annotation Count</th>
#               </tr>
#
#               <tr>
#                 <td class="lft">MISSENSE_VARIANT</td>
#                 <td>36</td>
#                 </tr>
#
#               <tr>
#                 <td class="lft">STOP_GAINED</td>
#                 <td>15</td>
#                 </tr>
#
#               <tr>
#                 <td class="lft">FRAMESHIFT_VARIANT</td>
#                 <td>14</td>
#                 </tr>
#
#            </tbody>

# %% [markdown]
# ## **Kabuki 2**Cohort

# %%
from IPython.display import HTML, display

from gpsea.view import CohortViewable
viewer = CohortViewable(hpo)
report = viewer.process(cohort=cohort_2, transcript_id=mane_tx_id_2)
display(HTML(report))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#     <style>
#     table {
#       border-collapse: collapse;
#       margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#     }
#
#     .table .column-1 {
#       text-align: left;
#     }
#     th {
#       background-color: LightSkyBlue;
#       border: 1px solid #dddddd;
#       text-align: left;
#       padding: 2px;
#       font-weight: bold;
#       font-size: 120%;
#     }
#
#     tr {
#       border: 1px solid #dddddd;
#     }
#
#     td {
#       padding: 2px;
#       font-weight: bold;
#     }
#
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#
#     .table td, tr {
#       text-align: right;
#     }
#
#     .lft {
#       text-align: left;
#     }
#
#     div {
#       display: block;
#       width: 100%;
#       padding-right: 1%;
#       margin-bottom: 20px; /* Add margin to separate divs */
#     }
#
#     caption {
#       caption-side: top;
#       text-align: left;
#       padding-bottom: 10px;
#       font-weight: bold;
#     }
#   </style>
# </head>
#
# <body>
#   <h1>GPSEA cohort analysis</h1>
#   <p>Successfully loaded 81 individuals.</p>
#
#   <p>No errors encountered.</p>
#
#
#     <table>
#     <caption style="color: black;">
#         <h3>Top 10 HPO Terms</h3>
#         A total of 127 HPO terms were used to annotated the cohort.
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">HPO Term</th>
#                 <th>ID</th>
#                 <th>Seen in <em>n</em> individuals</th>
#             </tr>
#
#             <tr>
#                 <td class="lft">Abnormal facial shape</td>
#                 <td>HP:0001999</td>
#                 <td>80</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Feeding difficulties</td>
#                 <td>HP:0011968</td>
#                 <td>55</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Delayed speech and language development</td>
#                 <td>HP:0000750</td>
#                 <td>54</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Hypotonia</td>
#                 <td>HP:0001252</td>
#                 <td>52</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Narrow palate</td>
#                 <td>HP:0000189</td>
#                 <td>38</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Prominent fingertip pads</td>
#                 <td>HP:0001212</td>
#                 <td>35</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Neonatal hypoglycemia</td>
#                 <td>HP:0001998</td>
#                 <td>31</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Delayed ability to walk</td>
#                 <td>HP:0031936</td>
#                 <td>31</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Motor delay</td>
#                 <td>HP:0001270</td>
#                 <td>27</td>
#                 </tr>
#
#             <tr>
#                 <td class="lft">Microcephaly</td>
#                 <td>HP:0000252</td>
#                 <td>24</td>
#                 </tr>
#
#                 </tbody>
#     </table>
#
#     <table>
#     <caption style="color: black;">
#         <h3>Top 10 Variants</h3>
#         Variants are shown according to NM_001291415.2. A total of 81 unique variants were identified in the cohort.
#     </caption>
#             <tbody>
#                 <tr class="strng">
#                     <th>Count</th>
#                     <th class="lft">Variant key</th>
#                     <th>Variant Name</th>
#                     <th>Protein Variant</th>
#                     <th>Variant Class</th>
#                 </tr>
#
#                 <tr>
#                     <td>10</td>
#                     <td class="lft">SO:1000029_HGNC:12637_KDM6A</td>
#                     <td>1000029_HGNC</td>
#                     <td>None</td>
#                     <td>TRANSCRIPT_ABLATION</td>
#                 </tr>
#
#                 <tr>
#                     <td>4</td>
#                     <td class="lft">X_45070166_45070170_CACAA_C</td>
#                     <td>c.2671_2674del</td>
#                     <td>p.Asn891ValfsTer27</td>
#                     <td>FRAMESHIFT_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">X_45020680_45020680_C_T</td>
#                     <td>c.514C>T</td>
#                     <td>p.Arg172Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">X_45090821_45090821_C_T</td>
#                     <td>c.3991C>T</td>
#                     <td>p.Arg1331Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">X_45059104_45059104_G_C</td>
#                     <td>c.974G>C</td>
#                     <td>p.Gly325Ala</td>
#                     <td>MISSENSE_VARIANT, SPLICE_REGION_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">X_44974688_44974688_C_G</td>
#                     <td>c.357C>G</td>
#                     <td>p.Tyr119Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#                 <tr>
#                     <td>3</td>
#                     <td class="lft">X_45010977_45010977_A_G</td>
#                     <td>c.401A>G</td>
#                     <td>p.Tyr134Cys</td>
#                     <td>MISSENSE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>2</td>
#                     <td class="lft">X_45090861_45090865_TTAAG_T</td>
#                     <td>c.4034+3_4034+6del</td>
#                     <td>None</td>
#                     <td>SPLICE_DONOR_VARIANT, CODING_SEQUENCE_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>2</td>
#                     <td class="lft">X_44974665_44974665_G_T</td>
#                     <td>c.335-1G>T</td>
#                     <td>None</td>
#                     <td>SPLICE_ACCEPTOR_VARIANT</td>
#                 </tr>
#
#                 <tr>
#                     <td>2</td>
#                     <td class="lft">X_45079316_45079316_C_T</td>
#                     <td>c.3265C>T</td>
#                     <td>p.Gln1089Ter</td>
#                     <td>STOP_GAINED</td>
#                 </tr>
#
#             </tbody>
#         </table>
#     <table>
#     <caption style="color: black;">
#         <h3>Diseases</h3>
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">Disease Name</th>
#                 <th >Disease ID</th>
#                 <th>Annotation Count</th>
#               </tr>
#
#               <tr>
#                 <td class="lft">Kabuki syndrome 2</td>
#                 <td>OMIM:300867</td>
#                 <td>81</td>
#                 </tr>
#
#            </tbody>
#     </table>
#
#     <table>
#     <caption style="color: black;">
#         <h3>Variant categories for NM_001291415.2</h3>
#     </caption>
#         <tbody>
#             <tr class="strng">
#                 <th class="lft">Variant effect</th>
#                 <th>Annotation Count</th>
#               </tr>
#
#               <tr>
#                 <td class="lft">FRAMESHIFT_VARIANT</td>
#                 <td>16</td>
#                 </tr>
#
#               <tr>
#                 <td class="lft">TRANSCRIPT_ABLATION</td>
#                 <td>10</td>
#                 </tr>
#
#               <tr>
#                 <td class="lft">SPLICE_ACCEPTOR_VARIANT</td>
#                 <td>6</td>
