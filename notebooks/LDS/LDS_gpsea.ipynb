# %% [markdown]
# # Loeys-Dietz syndrome
# Loeys-Dietz syndrome (LDS) is an autosomal dominant aortic aneurysm syndrome characterized by multisystemic involvement. The most typical clinical triad includes hypertelorism, bifid uvula or cleft palate and aortic aneurysm with tortuosity. Affected individuals may expereince aortic dissection at smaller aortic diameter and arterial aneurysms throughout the arterial tree. The genetic cause is heterogeneous and includes mutations in genes encoding for components of the transforming growth factor beta (TGFβ) signalling pathway: TGFBR1, TGFBR2, SMAD2, SMAD3, TGFB2 and TGFB3 (See [Velchev JD, et al. (2021). Loeys-Dietz Syndrome. Adv Exp Med Biol](https://pubmed.ncbi.nlm.nih.gov/34807423/)).
#
# This notebook will explore whether there are significant differences in phenotypic features between different genetic forms of LDS. We will include TGFBR1 and TGFBR2 (which were the first forms of LDS to be identified) with

# %%
import gpsea
import hpotk
from pyphetools.visualization import PhenopacketIngestor

store = hpotk.configure_ontology_store()
hpo = store.load_minimal_hpo(release='v2023-10-09')
print(f'Loaded HPO v{hpo.version}')
print(f"Using genophenocorr version {gpsea.__version__}")
# Out:
# Loaded HPO v2023-10-09
# Using genophenocorr version 0.5.1.dev0

# %% [markdown]
# ## LDS1
#
# Loeys Dietz syndrome 1 (LDS1) is caused by mutation in the TGFBR1 gene.

# %%
tgfbr1_symbol = 'TGFBR1'
tgfbr1_mane_tx_id = 'NM_004612.4'
tgfbr1_mane_protein_id = 'NP_004603.1' # TGF-beta receptor type-1 isoform 1 precursor"
lds1_disease_id = "OMIM:609192"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(tgfbr1_symbol))
tgfbr1_len = len(phenopackets)
lds1_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds1_disease_id)
# Out:
# Returning 23 phenopackets for disease OMIM:609192, ommiting 18 phenopackets.

# %% [markdown]
# # LDS2
# [Loeys-Dietz syndrome 2 (OMIM:610168)](https://omim.org/entry/610168) is caused by heterozygous mutation in the TGFBR2 gene.

# %%
tgfbr2_symbol = 'TGFBR2'
tgfbr2_mane_tx_id = 'NM_003242.6'
tgfbr2_mane_protein_id = 'NP_003233.4' # TGF-beta receptor type-2 isoform B precursor
lds2_disease_id = "OMIM:610168"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(tgfbr2_symbol))
tgfbr2_len = len(phenopackets)
lds2_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds2_disease_id)
# Out:
# Returning 47 phenopackets for disease OMIM:610168, ommiting 0 phenopackets.

# %% [markdown]
# # LDS3
# [Loeys-Dietz syndrome-3 (LDS3)](https://omim.org/entry/613795) is caused by heterozygous mutation in the SMAD3 gene.

# %%
smad3_symbol = 'SMAD3'
smad3_mane_tx_id = 'NM_005902.4'
smad3_mane_protein_id = 'NP_005893.1' # mothers against decapentaplegic homolog 3
lds3_disease_id = "OMIM:613795"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(smad3_symbol))

lds3_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds3_disease_id)
# Out:
# Returning 49 phenopackets for disease OMIM:613795, ommiting 0 phenopackets.

# %% [markdown]
# # LDS4
# [Loeys-Dietz syndrome-4 (LDS4)](https://omim.org/entry/614816) is caused by heterozygous mutation in the TGFB2 gene.

# %%
tgfb2_symbol = 'TGFB2'
tgfb2_mane_tx_id = 'NM_003238.6'
tgfb2_mane_protein_id = 'NP_003229.1' # transforming growth factor beta-2 proprotein isoform 2 preproprotein
lds4_disease_id = "OMIM:614816"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(tgfb2_symbol))

lds4_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds4_disease_id)
# Out:
# Returning 36 phenopackets for disease OMIM:614816, ommiting 0 phenopackets.

# %% [markdown]
# # LDS5
# [Loeys-Dietz syndrome-5 (LDS5)](https://omim.org/entry/615582) is caused by heterozygous mutation in the TGFB3 gene.

# %%
tgfb3_symbol = 'TGFB3'
tgfb3_mane_tx_id = 'NM_003239.5'
tgfb3_mane_protein_id = 'NP_003230.1' # transforming growth factor beta-3 proprotein isoform 1 preproprotein"
lds5_disease_id = "OMIM:615582"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(tgfb3_symbol))

lds5_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds5_disease_id)
# Out:
# Returning 43 phenopackets for disease OMIM:615582, ommiting 0 phenopackets.

# %% [markdown]
# # LDS6
# [Loeys-Dietz syndrome-6 (LDS6)](https://omim.org/entry/619656) is caused by heterozygous mutation in the SMAD2 gene

# %%
smad2_symbol = 'SMAD2'
smad2_mane_tx_id = 'NM_005901.6'
smad2_mane_protein_id = 'NP_005892.1' # mothers against decapentaplegic homolog 2 isoform 1

lds6_disease_id = "OMIM:619656"

from ppktstore.registry import configure_phenopacket_registry
phenopacket_registry = configure_phenopacket_registry()
with phenopacket_registry.open_phenopacket_store("0.1.20") as ps:
    phenopackets = tuple(ps.iter_cohort_phenopackets(smad2_symbol))

lds6_phenopackets = PhenopacketIngestor.filter_phenopackets(ppkt_list=phenopackets, disease_id=lds6_disease_id)
# Out:
# Returning 16 phenopackets for disease OMIM:619656, ommiting 0 phenopackets.

# %% [markdown]
# # LDS1 vs LDS2
# Here, we search for significant differences between LDS1 and LDS2

# %%
from ppktstore.registry import configure_phenopacket_registry
from gpsea.preprocessing import configure_caching_cohort_creator, load_phenopackets

lds1_and_lds2_phenopackets = list()
lds1_and_lds2_phenopackets.extend(lds1_phenopackets)
lds1_and_lds2_phenopackets.extend(lds2_phenopackets)
print(f"")

cohort_creator = configure_caching_cohort_creator(hpo)
lds1_lds2_cohort, validation = load_phenopackets(
    phenopackets=lds1_and_lds2_phenopackets, 
    cohort_creator=cohort_creator,
)

validation.summarize()
# Out:
# Individuals Processed: 100%|██████████| 70/70 [01:16<00:00,  1.10s/individuals]
# Validated under permissive policy
# No errors or warnings were found

# %%
from gpsea.analysis.predicate.phenotype import prepare_predicates_for_terms_of_interest

from gpsea.analysis.mtc_filter import HpoMtcFilter
mtc_filter = HpoMtcFilter.default_filter(
    hpo=hpo,
)
mtc_correction = 'fdr_bh'
mtc_alpha = 0.05
from gpsea.analysis.pcats.stats import FisherExactTest

count_statistic = FisherExactTest()
from gpsea.analysis.pcats import HpoTermAnalysis

analysis = HpoTermAnalysis(
    count_statistic=count_statistic,
    mtc_filter=mtc_filter,
    mtc_correction=mtc_correction,
    mtc_alpha=mtc_alpha,
)

# %%
from gpsea.analysis.predicate.genotype import diagnosis_predicate
from gpsea.view import MtcStatsViewer

lds1_lds2_pheno_predicates = prepare_predicates_for_terms_of_interest(
    cohort=lds1_lds2_cohort,
    hpo=hpo,
    missing_implies_excluded=False,
    min_n_of_patients_with_term=2,
)
len(f"Total of {len(lds1_lds2_pheno_predicates)} LDS1/LDS2pheno_predicates")

lds_1_2_disease_predicate = diagnosis_predicate(
    diagnoses=(lds1_disease_id, lds2_disease_id),
    labels=('LDS1', 'LDS2'),
)
print(lds_1_2_disease_predicate.display_question())
result = analysis.compare_genotype_vs_phenotypes(
    cohort=lds1_lds2_cohort,
    gt_predicate=lds_1_2_disease_predicate,
    pheno_predicates=lds1_lds2_pheno_predicates,
)


viewer = MtcStatsViewer()
viewer.process(result)
# Out:
# What disease was diagnosed: OMIM:609192, OMIM:610168
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#   <style>table {
#     border-collapse: collapse;
#     margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#   }
#
#
#   th {
#     background-color: #f2f2f2;
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 2px;
#   }
#
#   tr {
#     border: 1px solid #dddddd;
#   }
#
#   td {
#     padding: 2px;
#     font-weight: bold;
#   }
#
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#
#   .table td,tr {
#     text-align: left;
# }
#
# .table td:first-child, tr:first-child {
#     text-align: left;
# }
#
#   </style>
# </head>
#
# <body>
#   <h1>Phenotype testing report</h1>
#   <p>Phenotype MTC filter: <em>HPO MTC filter</em></p>
#   <p>Multiple testing correction: <em>fdr_bh</em></p>
#   <p>Performed statistical tests for 87 out of the total of 302 HPO terms.</p>
#     <table>
#       <caption>Using <em>HPO MTC filter</em>, 215 term(s) were omitted from statistical analysis.</caption>
#         <tbody>
#           <tr>
#             <th>Code</th>
#             <th>Reason</th>
#             <th>Count</th>
#           </tr>
#
#           <tr>
#             <td>HMF01</td>
#             <td>Skipping term with maximum frequency that was less than threshold 0.2</td>
#             <td>10</td>
#           </tr>
#
#           <tr>
#             <td>HMF03</td>
#             <td>Skipping term because of a child term with the same individual counts</td>
#             <td>11</td>
#           </tr>
#
#           <tr>
#             <td>HMF05</td>
#             <td>Skipping term because one genotype had zero observations</td>
#             <td>1</td>
#           </tr>
#
#           <tr>
#             <td>HMF08</td>
#             <td>Skipping general term</td>
#             <td>61</td>
#           </tr>
#
#           <tr>
#             <td>HMF09</td>
#             <td>Skipping term with maximum annotation frequency that was less than threshold 0.25</td>
#             <td>132</td>
#           </tr>
#
#         </tbody>
#     </table>
# </body>
# </html>

# %%
from gpsea.view import summarize_hpo_analysis

summarize_hpo_analysis(hpo=hpo, result=result)
# Out:
# What disease was diagnosed                  OMIM:609192         OMIM:610168  \
#                                                   Count Percent       Count
# Dolichocephaly [HP:0000268]                       12/13     92%        1/13
# Joint contracture [HP:0034392]                     3/14     21%         4/4
# Epicanthus [HP:0000286]                            3/13     23%       19/30
# Talipes equinovarus [HP:0001762]                   2/17     12%       11/24
# Bifid uvula [HP:0000193]                           4/16     25%       20/36
# ...                                                 ...     ...         ...
# Abnormal sternum morphology [HP:0000766]            9/9    100%       17/17
# Abnormal thorax morphology [HP:0000765]             9/9    100%       17/17
# Abnormal brain morphology [HP:0012443]              1/1    100%       19/19
# Downslanted palpebral fissures [HP:0000494]         1/2     50%        7/20
# Ascending aortic dissection [HP:0004933]            1/4     25%        4/14
#
# What disease was diagnosed                                              \
#                                             Percent Corrected p values
# Dolichocephaly [HP:0000268]                      8%           0.002844
# Joint contracture [HP:0034392]                 100%           0.497549
# Epicanthus [HP:0000286]                         63%           0.629165
# Talipes equinovarus [HP:0001762]                46%           0.850727
# Bifid uvula [HP:0000193]                        56%           1.000000
# ...                                             ...                ...
# Abnormal sternum morphology [HP:0000766]       100%           1.000000
# Abnormal thorax morphology [HP:0000765]        100%           1.000000
# Abnormal brain morphology [HP:0012443]         100%           1.000000
# Downslanted palpebral fissures [HP:0000494]     35%           1.000000
# Ascending aortic dissection [HP:0004933]        29%           1.000000
#
# What disease was diagnosed
#                                              p values
# Dolichocephaly [HP:0000268]                  0.000033
# Joint contracture [HP:0034392]               0.011438
# Epicanthus [HP:0000286]                      0.021695
# Talipes equinovarus [HP:0001762]             0.039114
# Bifid uvula [HP:0000193]                     0.069543
# ...                                               ...
# Abnormal sternum morphology [HP:0000766]     1.000000
# Abnormal thorax morphology [HP:0000765]      1.000000
# Abnormal brain morphology [HP:0012443]       1.000000
# Downslanted palpebral fissures [HP:0000494]  1.000000
# Ascending aortic dissection [HP:0004933]     1.000000
#
# [87 rows x 6 columns]

# %% [markdown]
# # LDS1 vs LDS3

# %%
from ppktstore.registry import configure_phenopacket_registry
from gpsea.preprocessing import configure_caching_cohort_creator, load_phenopackets

lds1_and_lds3_phenopackets = list()
lds1_and_lds3_phenopackets.extend(lds1_phenopackets)
lds1_and_lds3_phenopackets.extend(lds3_phenopackets)
print(f"Got {len(lds1_and_lds3_phenopackets)} LDS1 and LDS3 phenopackets")

cohort_creator = configure_caching_cohort_creator(hpo)
lds1_lds3_cohort, validation = load_phenopackets(
    phenopackets=lds1_and_lds3_phenopackets, 
    cohort_creator=cohort_creator,
)

validation.summarize()
# Out:
# Got 72 LDS1 and LDS3 phenopackets
# Individuals Processed: 100%|██████████| 72/72 [00:13<00:00,  5.19individuals/s]
# Validated under permissive policy
# No errors or warnings were found

# %%
lds1_lds3_pheno_predicates = prepare_predicates_for_terms_of_interest(
    cohort=lds1_lds3_cohort,
    hpo=hpo,
    missing_implies_excluded=False,
    min_n_of_patients_with_term=2,
)
len(f"Total of {len(lds1_lds3_pheno_predicates)} LDS1/LDS3pheno_predicates")

lds_1_3_disease_predicate = diagnosis_predicate(
    diagnoses=(lds1_disease_id, lds3_disease_id),
    labels=('LDS1', 'LDS3'),
)
print(lds_1_3_disease_predicate.display_question())
lds1_3_result = analysis.compare_genotype_vs_phenotypes(
    cohort=lds1_lds3_cohort,
    gt_predicate=lds_1_3_disease_predicate,
    pheno_predicates=lds1_lds3_pheno_predicates,
)


viewer = MtcStatsViewer()
viewer.process(lds1_3_result)
# Out:
# What disease was diagnosed: OMIM:609192, OMIM:613795
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#   <style>table {
#     border-collapse: collapse;
#     margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#   }
#
#
#   th {
#     background-color: #f2f2f2;
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 2px;
#   }
#
#   tr {
#     border: 1px solid #dddddd;
#   }
#
#   td {
#     padding: 2px;
#     font-weight: bold;
#   }
#
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#
#   .table td,tr {
#     text-align: left;
# }
#
# .table td:first-child, tr:first-child {
#     text-align: left;
# }
#
#   </style>
# </head>
#
# <body>
#   <h1>Phenotype testing report</h1>
#   <p>Phenotype MTC filter: <em>HPO MTC filter</em></p>
#   <p>Multiple testing correction: <em>fdr_bh</em></p>
#   <p>Performed statistical tests for 38 out of the total of 244 HPO terms.</p>
#     <table>
#       <caption>Using <em>HPO MTC filter</em>, 206 term(s) were omitted from statistical analysis.</caption>
#         <tbody>
#           <tr>
#             <th>Code</th>
#             <th>Reason</th>
#             <th>Count</th>
#           </tr>
#
#           <tr>
#             <td>HMF01</td>
#             <td>Skipping term with maximum frequency that was less than threshold 0.2</td>
#             <td>18</td>
#           </tr>
#
#           <tr>
#             <td>HMF02</td>
#             <td>Skipping term because no genotype has more than one observed HPO count</td>
#             <td>1</td>
#           </tr>
#
#           <tr>
#             <td>HMF03</td>
#             <td>Skipping term because of a child term with the same individual counts</td>
#             <td>6</td>
#           </tr>
#
#           <tr>
#             <td>HMF05</td>
#             <td>Skipping term because one genotype had zero observations</td>
#             <td>7</td>
#           </tr>
#
#           <tr>
#             <td>HMF08</td>
#             <td>Skipping general term</td>
#             <td>57</td>
#           </tr>
#
#           <tr>
#             <td>HMF09</td>
#             <td>Skipping term with maximum annotation frequency that was less than threshold 0.25</td>
#             <td>117</td>
#           </tr>
#
#         </tbody>
#     </table>
# </body>
# </html>

# %%
summarize_hpo_analysis(hpo=hpo, result=lds1_3_result)
# Out:
# What disease was diagnosed                         OMIM:609192          \
#                                                          Count Percent
# Aortic root aneurysm [HP:0002616]                        11/11    100%
# Osteoarthritis [HP:0002758]                               0/11      0%
# Abnormal sternum morphology [HP:0000766]                   9/9    100%
# Craniosynostosis [HP:0001363]                              4/8     50%
# Scoliosis [HP:0002650]                                   18/21     86%
# Varicose veins [HP:0002619]                               1/12      8%
# Pes planus [HP:0001763]                                  11/14     79%
# Aortic aneurysm [HP:0004942]                             11/11    100%
# Hypertelorism [HP:0000316]                               15/19     79%
# Pectus carinatum [HP:0000768]                             7/18     39%
# Blue sclerae [HP:0000592]                                 6/18     33%
# Joint hypermobility [HP:0001382]                         12/19     63%
# Mitral valve prolapse [HP:0001634]                        8/21     38%
# Aortic dissection [HP:0002647]                             1/1    100%
# Striae distensae [HP:0001065]                             7/14     50%
# Pectus excavatum [HP:0000767]                             3/14     21%
# High palate [HP:0000218]                                 12/16     75%
# Inguinal hernia [HP:0000023]                              6/14     43%
# Arterial tortuosity [HP:0005116]                          9/17     53%
# Disproportionate tall stature [HP:0001519]                9/17     53%
# Bifid uvula [HP:0000193]                                  4/16     25%
# Abnormal oral cavity morphology [HP:0000163]             17/17    100%
# Abnormal palate morphology [HP:0000174]                  17/17    100%
# Abnormal axial skeleton morphology [HP:0009121]          21/21    100%
# Abnormal curvature of the vertebral column [HP:...       18/18    100%
# Abnormality of the vertebral column [HP:0000925]         19/19    100%
# Arachnodactyly [HP:0001166]                               8/18     44%
# Vascular dilatation [HP:0002617]                         11/11    100%
# Abnormal blood vessel morphology [HP:0033353]            15/15    100%
# Abnormal aortic morphology [HP:0001679]                  11/11    100%
# Abnormal morphology of the great vessels [HP:00...       12/12    100%
# Abnormal systemic arterial morphology [HP:0011004]       14/14    100%
# Vascular tortuosity [HP:0004948]                           9/9    100%
# Abnormality of joint mobility [HP:0011729]               12/12    100%
# Soft skin [HP:0000977]                                     3/5     60%
# Abnormal elasticity of skin [HP:0010647]                 10/10    100%
# Abnormal joint morphology [HP:0001367]                     4/4    100%
# Hernia of the abdominal wall [HP:0004299]                  6/6    100%
#
# What disease was diagnosed                         OMIM:613795          \
#                                                          Count Percent
# Aortic root aneurysm [HP:0002616]                         0/22      0%
# Osteoarthritis [HP:0002758]                              26/38     68%
# Abnormal sternum morphology [HP:0000766]                  6/20     30%
# Craniosynostosis [HP:0001363]                             0/27      0%
# Scoliosis [HP:0002650]                                   20/43     47%
# Varicose veins [HP:0002619]                              14/22     64%
# Pes planus [HP:0001763]                                   4/17     24%
# Aortic aneurysm [HP:0004942]                             26/48     54%
# Hypertelorism [HP:0000316]                               13/35     37%
# Pectus carinatum [HP:0000768]                             0/14      0%
# Blue sclerae [HP:0000592]                                 1/20      5%
# Joint hypermobility [HP:0001382]                         12/36     33%
# Mitral valve prolapse [HP:0001634]                        3/22     14%
# Aortic dissection [HP:0002647]                            2/22      9%
# Striae distensae [HP:0001065]                             4/20     20%
# Pectus excavatum [HP:0000767]                             0/14      0%
# High palate [HP:0000218]                                 12/20     60%
# Inguinal hernia [HP:0000023]                             12/39     31%
# Arterial tortuosity [HP:0005116]                         11/26     42%
# Disproportionate tall stature [HP:0001519]                8/19     42%
# Bifid uvula [HP:0000193]                                 13/38     34%
# Abnormal oral cavity morphology [HP:0000163]             24/24    100%
# Abnormal palate morphology [HP:0000174]                  24/24    100%
# Abnormal axial skeleton morphology [HP:0009121]          33/33    100%
# Abnormal curvature of the vertebral column [HP:...       20/20    100%
# Abnormality of the vertebral column [HP:0000925]         31/31    100%
# Arachnodactyly [HP:0001166]                               7/18     39%
# Vascular dilatation [HP:0002617]                         26/26    100%
# Abnormal blood vessel morphology [HP:0033353]            32/32    100%
# Abnormal aortic morphology [HP:0001679]                  26/26    100%
# Abnormal morphology of the great vessels [HP:00...       26/26    100%
# Abnormal systemic arterial morphology [HP:0011004]       29/29    100%
# Vascular tortuosity [HP:0004948]                         11/11    100%
# Abnormality of joint mobility [HP:0011729]               12/12    100%
# Soft skin [HP:0000977]                                   23/37     62%
# Abnormal elasticity of skin [HP:0010647]                 25/25    100%
# Abnormal joint morphology [HP:0001367]                   26/26    100%
# Hernia of the abdominal wall [HP:0004299]                12/12    100%
#
# What disease was diagnosed                                             \
#                                                    Corrected p values
# Aortic root aneurysm [HP:0002616]                        1.963452e-07
# Osteoarthritis [HP:0002758]                              8.817118e-04
# Abnormal sternum morphology [HP:0000766]                 8.862236e-03
# Craniosynostosis [HP:0001363]                            1.270053e-02
# Scoliosis [HP:0002650]                                   1.892136e-02
# Varicose veins [HP:0002619]                              1.892136e-02
# Pes planus [HP:0001763]                                  1.892136e-02
# Aortic aneurysm [HP:0004942]                             1.892136e-02
# Hypertelorism [HP:0000316]                               1.892136e-02
# Pectus carinatum [HP:0000768]                            3.980349e-02
# Blue sclerae [HP:0000592]                                1.315613e-01
# Joint hypermobility [HP:0001382]                         1.490537e-01
# Mitral valve prolapse [HP:0001634]                       2.582226e-01
# Aortic dissection [HP:0002647]                           3.408306e-01
# Striae distensae [HP:0001065]                            3.408306e-01
# Pectus excavatum [HP:0000767]                            5.277778e-01
# High palate [HP:0000218]                                 1.000000e+00
# Inguinal hernia [HP:0000023]                             1.000000e+00
# Arterial tortuosity [HP:0005116]                         1.000000e+00
# Disproportionate tall stature [HP:0001519]               1.000000e+00
# Bifid uvula [HP:0000193]                                 1.000000e+00
# Abnormal oral cavity morphology [HP:0000163]             1.000000e+00
# Abnormal palate morphology [HP:0000174]                  1.000000e+00
# Abnormal axial skeleton morphology [HP:0009121]          1.000000e+00
# Abnormal curvature of the vertebral column [HP:...       1.000000e+00
# Abnormality of the vertebral column [HP:0000925]         1.000000e+00
# Arachnodactyly [HP:0001166]                              1.000000e+00
# Vascular dilatation [HP:0002617]                         1.000000e+00
# Abnormal blood vessel morphology [HP:0033353]            1.000000e+00
# Abnormal aortic morphology [HP:0001679]                  1.000000e+00
# Abnormal morphology of the great vessels [HP:00...       1.000000e+00
# Abnormal systemic arterial morphology [HP:0011004]       1.000000e+00
# Vascular tortuosity [HP:0004948]                         1.000000e+00
# Abnormality of joint mobility [HP:0011729]               1.000000e+00
# Soft skin [HP:0000977]                                   1.000000e+00
# Abnormal elasticity of skin [HP:0010647]                 1.000000e+00
# Abnormal joint morphology [HP:0001367]                   1.000000e+00
# Hernia of the abdominal wall [HP:0004299]                1.000000e+00
#
# What disease was diagnosed
#                                                         p values
# Aortic root aneurysm [HP:0002616]                   5.166978e-09
# Osteoarthritis [HP:0002758]                         4.640589e-05
# Abnormal sternum morphology [HP:0000766]            6.996502e-04
# Craniosynostosis [HP:0001363]                       1.336898e-03
# Scoliosis [HP:0002650]                              3.014785e-03
# Varicose veins [HP:0002619]                         3.143993e-03
# Pes planus [HP:0001763]                             3.847595e-03
# Aortic aneurysm [HP:0004942]                        4.326643e-03
# Hypertelorism [HP:0000316]                          4.481374e-03
# Pectus carinatum [HP:0000768]                       1.047460e-02
# Blue sclerae [HP:0000592]                           3.808354e-02
# Joint hypermobility [HP:0001382]                    4.706959e-02
# Mitral valve prolapse [HP:0001634]                  8.833931e-02
# Aortic dissection [HP:0002647]                      1.304348e-01
# Striae distensae [HP:0001065]                       1.345384e-01
# Pectus excavatum [HP:0000767]                       2.222222e-01
# High palate [HP:0000218]                            4.814980e-01
# Inguinal hernia [HP:0000023]                        5.146725e-01
# Arterial tortuosity [HP:0005116]                    5.450087e-01
# Disproportionate tall stature [HP:0001519]          7.387950e-01
# Bifid uvula [HP:0000193]                            7.491960e-01
# Abnormal oral cavity morphology [HP:0000163]        1.000000e+00
# Abnormal palate morphology [HP:0000174]             1.000000e+00
# Abnormal axial skeleton morphology [HP:0009121]     1.000000e+00
# Abnormal curvature of the vertebral column [HP:...  1.000000e+00
# Abnormality of the vertebral column [HP:0000925]    1.000000e+00
# Arachnodactyly [HP:0001166]                         1.000000e+00
# Vascular dilatation [HP:0002617]                    1.000000e+00
# Abnormal blood vessel morphology [HP:0033353]       1.000000e+00
# Abnormal aortic morphology [HP:0001679]             1.000000e+00
# Abnormal morphology of the great vessels [HP:00...  1.000000e+00
# Abnormal systemic arterial morphology [HP:0011004]  1.000000e+00
# Vascular tortuosity [HP:0004948]                    1.000000e+00
# Abnormality of joint mobility [HP:0011729]          1.000000e+00
# Soft skin [HP:0000977]                              1.000000e+00
# Abnormal elasticity of skin [HP:0010647]            1.000000e+00
# Abnormal joint morphology [HP:0001367]              1.000000e+00
# Hernia of the abdominal wall [HP:0004299]           1.000000e+00

# %% [markdown]
# # LDS3 vs LDS6
# (SMAD3 and SMA2)

# %%
lds3_and_lds6_phenopackets = list()
lds3_and_lds6_phenopackets.extend(lds3_phenopackets)
lds3_and_lds6_phenopackets.extend(lds6_phenopackets)
print(f"Got {len(lds3_and_lds6_phenopackets)} LDS3 and LDS6 phenopackets")

cohort_creator = configure_caching_cohort_creator(hpo)
lds3_lds6_cohort, validation = load_phenopackets(
    phenopackets=lds3_and_lds6_phenopackets, 
    cohort_creator=cohort_creator,
)

validation.summarize()
# Out:
# Got 65 LDS3 and LDS6 phenopackets
# Individuals Processed: 100%|██████████| 65/65 [00:00<00:00, 615.11individuals/s]
# Validated under permissive policy
# No errors or warnings were found

# %%
lds3_lds6_pheno_predicates = prepare_predicates_for_terms_of_interest(
    cohort=lds3_lds6_cohort,
    hpo=hpo,
    missing_implies_excluded=False,
    min_n_of_patients_with_term=2,
)
len(f"Total of {len(lds3_lds6_pheno_predicates)} LDS3/LDS6pheno_predicates")

lds_3_6_disease_predicate = diagnosis_predicate(
    diagnoses=(lds3_disease_id, lds6_disease_id),
    labels=('LDS3', 'LDS6'),
)
print(lds_3_6_disease_predicate.display_question())
lds3_6_result = analysis.compare_genotype_vs_phenotypes(
    cohort=lds3_lds6_cohort,
    gt_predicate=lds_3_6_disease_predicate,
    pheno_predicates=lds3_lds6_pheno_predicates,
)


viewer = MtcStatsViewer()
viewer.process(lds3_6_result)
# Out:
# What disease was diagnosed: OMIM:613795, OMIM:619656
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#   <style>table {
#     border-collapse: collapse;
#     margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#   }
#
#
#   th {
#     background-color: #f2f2f2;
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 2px;
#   }
#
#   tr {
#     border: 1px solid #dddddd;
#   }
#
#   td {
#     padding: 2px;
#     font-weight: bold;
#   }
#
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#
#   .table td,tr {
#     text-align: left;
# }
#
# .table td:first-child, tr:first-child {
#     text-align: left;
# }
#
#   </style>
# </head>
#
# <body>
#   <h1>Phenotype testing report</h1>
#   <p>Phenotype MTC filter: <em>HPO MTC filter</em></p>
#   <p>Multiple testing correction: <em>fdr_bh</em></p>
#   <p>Performed statistical tests for 37 out of the total of 156 HPO terms.</p>
#     <table>
#       <caption>Using <em>HPO MTC filter</em>, 119 term(s) were omitted from statistical analysis.</caption>
#         <tbody>
#           <tr>
#             <th>Code</th>
#             <th>Reason</th>
#             <th>Count</th>
#           </tr>
#
#           <tr>
#             <td>HMF01</td>
#             <td>Skipping term with maximum frequency that was less than threshold 0.2</td>
#             <td>8</td>
#           </tr>
#
#           <tr>
#             <td>HMF03</td>
#             <td>Skipping term because of a child term with the same individual counts</td>
#             <td>6</td>
#           </tr>
#
#           <tr>
#             <td>HMF08</td>
#             <td>Skipping general term</td>
#             <td>47</td>
#           </tr>
#
#           <tr>
#             <td>HMF09</td>
#             <td>Skipping term with maximum annotation frequency that was less than threshold 0.25</td>
#             <td>58</td>
#           </tr>
#
#         </tbody>
#     </table>
# </body>
# </html>

# %%
summarize_hpo_analysis(hpo=hpo, result=lds3_6_result)
# Out:
# What disease was diagnosed                         OMIM:613795          \
#                                                          Count Percent
# Thoracic aortic aneurysm [HP:0012727]                     0/22      0%
# Aortic aneurysm [HP:0004942]                             26/48     54%
# Soft skin [HP:0000977]                                   23/37     62%
# Tall stature [HP:0000098]                                  8/8    100%
# Bifid uvula [HP:0000193]                                 13/38     34%
# Osteochondritis dissecans [HP:0010886]                   13/18     72%
# Disproportionate tall stature [HP:0001519]                8/19     42%
# Varicose veins [HP:0002619]                              14/22     64%
# High palate [HP:0000218]                                 12/20     60%
# Intervertebral disc degeneration [HP:0008419]            18/20     90%
# Arterial tortuosity [HP:0005116]                         11/26     42%
# Inguinal hernia [HP:0000023]                             12/39     31%
# Umbilical hernia [HP:0001537]                            12/39     31%
# Hypertelorism [HP:0000316]                               13/35     37%
# Osteoarthritis [HP:0002758]                              26/38     68%
# Arthritis [HP:0001369]                                   26/26    100%
# Abnormal joint morphology [HP:0001367]                   26/26    100%
# Abnormal intervertebral disk morphology [HP:000...       18/18    100%
# Abnormality of the vertebral column [HP:0000925]         31/31    100%
# Abnormal axial skeleton morphology [HP:0009121]          33/33    100%
# Vascular dilatation [HP:0002617]                         26/26    100%
# Abnormal blood vessel morphology [HP:0033353]            32/32    100%
# Abnormal aortic morphology [HP:0001679]                  26/26    100%
# Abnormal systemic arterial morphology [HP:0011004]       29/29    100%
# Abnormal sternum morphology [HP:0000766]                  6/20     30%
# Scoliosis [HP:0002650]                                   20/43     47%
# Abnormal curvature of the vertebral column [HP:...       20/20    100%
# Abnormal palate morphology [HP:0000174]                  24/24    100%
# Joint hypermobility [HP:0001382]                         12/36     33%
# Hernia of the abdominal wall [HP:0004299]                12/12    100%
# Hernia [HP:0100790]                                      12/12    100%
# Abnormal elasticity of skin [HP:0010647]                 25/25    100%
# Pes planus [HP:0001763]                                   4/17     24%
# Arachnodactyly [HP:0001166]                               7/18     39%
# Striae distensae [HP:0001065]                             4/20     20%
# Venous insufficiency [HP:0005293]                        14/14    100%
# Dilatation of the cerebral artery [HP:0004944]            2/11     18%
#
# What disease was diagnosed                         OMIM:619656          \
#                                                          Count Percent
# Thoracic aortic aneurysm [HP:0012727]                    10/15     67%
# Aortic aneurysm [HP:0004942]                             10/10    100%
# Soft skin [HP:0000977]                                     0/4      0%
# Tall stature [HP:0000098]                                 5/10     50%
# Bifid uvula [HP:0000193]                                  1/14      7%
# Osteochondritis dissecans [HP:0010886]                     0/2      0%
# Disproportionate tall stature [HP:0001519]                 0/5      0%
# Varicose veins [HP:0002619]                               4/12     33%
# High palate [HP:0000218]                                  5/15     33%
# Intervertebral disc degeneration [HP:0008419]              3/4     75%
# Arterial tortuosity [HP:0005116]                           1/1    100%
# Inguinal hernia [HP:0000023]                              5/11     45%
# Umbilical hernia [HP:0001537]                              2/4     50%
# Hypertelorism [HP:0000316]                                4/14     29%
# Osteoarthritis [HP:0002758]                                2/2    100%
# Arthritis [HP:0001369]                                     2/2    100%
# Abnormal joint morphology [HP:0001367]                     2/2    100%
# Abnormal intervertebral disk morphology [HP:000...         3/3    100%
# Abnormality of the vertebral column [HP:0000925]           8/8    100%
# Abnormal axial skeleton morphology [HP:0009121]            9/9    100%
# Vascular dilatation [HP:0002617]                         11/11    100%
# Abnormal blood vessel morphology [HP:0033353]            15/15    100%
# Abnormal aortic morphology [HP:0001679]                  10/10    100%
# Abnormal systemic arterial morphology [HP:0011004]       14/14    100%
# Abnormal sternum morphology [HP:0000766]                  3/13     23%
# Scoliosis [HP:0002650]                                    5/12     42%
# Abnormal curvature of the vertebral column [HP:...         5/5    100%
# Abnormal palate morphology [HP:0000174]                    6/6    100%
# Joint hypermobility [HP:0001382]                           1/5     20%
# Hernia of the abdominal wall [HP:0004299]                  5/5    100%
# Hernia [HP:0100790]                                        7/7    100%
# Abnormal elasticity of skin [HP:0010647]                   1/1    100%
# Pes planus [HP:0001763]                                   3/10     30%
# Arachnodactyly [HP:0001166]                               6/14     43%
# Striae distensae [HP:0001065]                              1/5     20%
# Venous insufficiency [HP:0005293]                          4/4    100%
# Dilatation of the cerebral artery [HP:0004944]             2/8     25%
#
# What disease was diagnosed                                             \
#                                                    Corrected p values
# Thoracic aortic aneurysm [HP:0012727]                        0.000319
# Aortic aneurysm [HP:0004942]                                 0.168124
# Soft skin [HP:0000977]                                       0.332516
# Tall stature [HP:0000098]                                    0.332516
# Bifid uvula [HP:0000193]                                     0.577972
# Osteochondritis dissecans [HP:0010886]                       0.681579
# Disproportionate tall stature [HP:0001519]                   0.689441
# Varicose veins [HP:0002619]                                  0.700293
# High palate [HP:0000218]                                     0.721842
# Intervertebral disc degeneration [HP:0008419]                1.000000
# Arterial tortuosity [HP:0005116]                             1.000000
# Inguinal hernia [HP:0000023]                                 1.000000
# Umbilical hernia [HP:0001537]                                1.000000
# Hypertelorism [HP:0000316]                                   1.000000
# Osteoarthritis [HP:0002758]                                  1.000000
# Arthritis [HP:0001369]                                       1.000000
# Abnormal joint morphology [HP:0001367]                       1.000000
# Abnormal intervertebral disk morphology [HP:000...           1.000000
# Abnormality of the vertebral column [HP:0000925]             1.000000
# Abnormal axial skeleton morphology [HP:0009121]              1.000000
# Vascular dilatation [HP:0002617]                             1.000000
# Abnormal blood vessel morphology [HP:0033353]                1.000000
# Abnormal aortic morphology [HP:0001679]                      1.000000
# Abnormal systemic arterial morphology [HP:0011004]           1.000000
# Abnormal sternum morphology [HP:0000766]                     1.000000
# Scoliosis [HP:0002650]                                       1.000000
# Abnormal curvature of the vertebral column [HP:...           1.000000
# Abnormal palate morphology [HP:0000174]                      1.000000
# Joint hypermobility [HP:0001382]                             1.000000
# Hernia of the abdominal wall [HP:0004299]                    1.000000
# Hernia [HP:0100790]                                          1.000000
# Abnormal elasticity of skin [HP:0010647]                     1.000000
# Pes planus [HP:0001763]                                      1.000000
# Arachnodactyly [HP:0001166]                                  1.000000
# Striae distensae [HP:0001065]                                1.000000
# Venous insufficiency [HP:0005293]                            1.000000
# Dilatation of the cerebral artery [HP:0004944]               1.000000
#
# What disease was diagnosed
#                                                     p values
# Thoracic aortic aneurysm [HP:0012727]               0.000009
# Aortic aneurysm [HP:0004942]                        0.009088
# Soft skin [HP:0000977]                              0.030216
# Tall stature [HP:0000098]                           0.035948
# Bifid uvula [HP:0000193]                            0.078104
# Osteochondritis dissecans [HP:0010886]              0.110526
# Disproportionate tall stature [HP:0001519]          0.130435
# Varicose veins [HP:0002619]                         0.151415
# High palate [HP:0000218]                            0.175583
# Intervertebral disc degeneration [HP:0008419]       0.436759
# Arterial tortuosity [HP:0005116]                    0.444444
# Inguinal hernia [HP:0000023]                        0.475054
# Umbilical hernia [HP:0001537]                       0.585479
# Hypertelorism [HP:0000316]                          0.742960
# Osteoarthritis [HP:0002758]                         1.000000
# Arthritis [HP:0001369]                              1.000000
# Abnormal joint morphology [HP:0001367]              1.000000
# Abnormal intervertebral disk morphology [HP:000...  1.000000
# Abnormality of the vertebral column [HP:0000925]    1.000000
# Abnormal axial skeleton morphology [HP:0009121]     1.000000
# Vascular dilatation [HP:0002617]                    1.000000
# Abnormal blood vessel morphology [HP:0033353]       1.000000
# Abnormal aortic morphology [HP:0001679]             1.000000
# Abnormal systemic arterial morphology [HP:0011004]  1.000000
# Abnormal sternum morphology [HP:0000766]            1.000000
# Scoliosis [HP:0002650]                              1.000000
# Abnormal curvature of the vertebral column [HP:...  1.000000
# Abnormal palate morphology [HP:0000174]             1.000000
# Joint hypermobility [HP:0001382]                    1.000000
# Hernia of the abdominal wall [HP:0004299]           1.000000
# Hernia [HP:0100790]                                 1.000000
# Abnormal elasticity of skin [HP:0010647]            1.000000
# Pes planus [HP:0001763]                             1.000000
# Arachnodactyly [HP:0001166]                         1.000000
# Striae distensae [HP:0001065]                       1.000000
# Venous insufficiency [HP:0005293]                   1.000000
# Dilatation of the cerebral artery [HP:0004944]      1.000000

# %% [markdown]
# # LDS2 vs LDS6

# %%
lds1_and_lds6_phenopackets = list()
lds1_and_lds6_phenopackets.extend(lds1_phenopackets)
lds1_and_lds6_phenopackets.extend(lds6_phenopackets)
print(f"Got {len(lds1_and_lds6_phenopackets)} LDS1 and LDS6 phenopackets")

cohort_creator = configure_caching_cohort_creator(hpo)
lds1_lds6_cohort, validation = load_phenopackets(
    phenopackets=lds1_and_lds6_phenopackets, 
    cohort_creator=cohort_creator,
)

validation.summarize()
# Out:
# Got 39 LDS1 and LDS6 phenopackets
# Individuals Processed: 100%|██████████| 39/39 [00:00<00:00, 261.39individuals/s]
# Validated under permissive policy
# No errors or warnings were found

# %%
lds1_lds6_pheno_predicates = prepare_predicates_for_terms_of_interest(
    cohort=lds1_lds6_cohort,
    hpo=hpo,
    missing_implies_excluded=False,
    min_n_of_patients_with_term=2,
)
len(f"Total of {len(lds1_lds6_pheno_predicates)} LDS3/LDS6pheno_predicates")

lds_1_6_disease_predicate = diagnosis_predicate(
    diagnoses=(lds1_disease_id, lds6_disease_id),
    labels=('LDS1', 'LDS6'),
)
print(lds_1_6_disease_predicate.display_question())
lds1_6_result = analysis.compare_genotype_vs_phenotypes(
    cohort=lds1_lds6_cohort,
    gt_predicate=lds_1_6_disease_predicate,
    pheno_predicates=lds1_lds6_pheno_predicates,
)


viewer = MtcStatsViewer()
viewer.process(lds1_6_result)
# Out:
# What disease was diagnosed: OMIM:609192, OMIM:619656
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <title>Cohort</title>
#   <style>table {
#     border-collapse: collapse;
#     margin: 25px 0;
#       font-size: 0.9em;
#       font-family: sans-serif;
#       min-width: 400px;
#       box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#   }
#
#
#   th {
#     background-color: #f2f2f2;
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 2px;
#   }
#
#   tr {
#     border: 1px solid #dddddd;
#   }
#
#   td {
#     padding: 2px;
#     font-weight: bold;
#   }
#
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#
#   .table td,tr {
#     text-align: left;
# }
#
# .table td:first-child, tr:first-child {
#     text-align: left;
# }
#
#   </style>
# </head>
#
# <body>
#   <h1>Phenotype testing report</h1>
#   <p>Phenotype MTC filter: <em>HPO MTC filter</em></p>
#   <p>Multiple testing correction: <em>fdr_bh</em></p>
#   <p>Performed statistical tests for 47 out of the total of 249 HPO terms.</p>
#     <table>
#       <caption>Using <em>HPO MTC filter</em>, 202 term(s) were omitted from statistical analysis.</caption>
#         <tbody>
#           <tr>
#             <th>Code</th>
#             <th>Reason</th>
#             <th>Count</th>
#           </tr>
#
#           <tr>
#             <td>HMF01</td>
#             <td>Skipping term with maximum frequency that was less than threshold 0.2</td>
#             <td>17</td>
#           </tr>
#
#           <tr>
#             <td>HMF03</td>
#             <td>Skipping term because of a child term with the same individual counts</td>
#             <td>8</td>
#           </tr>
#
#           <tr>
#             <td>HMF05</td>
#             <td>Skipping term because one genotype had zero observations</td>
#             <td>25</td>
#           </tr>
#
#           <tr>
#             <td>HMF08</td>
#             <td>Skipping general term</td>
#             <td>58</td>
#           </tr>
#
#           <tr>
#             <td>HMF09</td>
#             <td>Skipping term with maximum annotation frequency that was less than threshold 0.25</td>
#             <td>94</td>
#           </tr>
#
#         </tbody>
#     </table>
# </body>
# </html>

# %%
summarize_hpo_analysis(hpo=hpo, result=lds1_6_result)
# Out:
# What disease was diagnosed                         OMIM:609192          \
#                                                          Count Percent
# Aortic root aneurysm [HP:0002616]                        11/11    100%
# Abnormal sternum morphology [HP:0000766]                   9/9    100%
# Dolichocephaly [HP:0000268]                              12/13     92%
# Hypertelorism [HP:0000316]                               15/19     79%
# Osteoarthritis [HP:0002758]                               0/11      0%
# Scoliosis [HP:0002650]                                   18/21     86%
# Pectus carinatum [HP:0000768]                             7/18     39%
# High palate [HP:0000218]                                 12/16     75%
# Tall stature [HP:0000098]                                  9/9    100%
# Pes planus [HP:0001763]                                  11/14     79%
# Thoracic aortic aneurysm [HP:0012727]                    11/11    100%
# Disproportionate tall stature [HP:0001519]                9/17     53%
# Dermal translucency [HP:0010648]                         11/16     69%
# Joint hypermobility [HP:0001382]                         12/19     63%
# Pectus excavatum [HP:0000767]                             3/14     21%
# Varicose veins [HP:0002619]                               1/12      8%
# Bifid uvula [HP:0000193]                                  4/16     25%
# Striae distensae [HP:0001065]                             7/14     50%
# Downslanted palpebral fissures [HP:0000494]                1/2     50%
# Bruising susceptibility [HP:0000978]                      5/12     42%
# Abnormal oral cavity morphology [HP:0000163]             17/17    100%
# Abnormal palate morphology [HP:0000174]                  17/17    100%
# Abnormal axial skeleton morphology [HP:0009121]          21/21    100%
# Abnormal midface morphology [HP:0000309]                 14/14    100%
# Abnormal curvature of the vertebral column [HP:...       18/18    100%
# Abnormality of the vertebral column [HP:0000925]         19/19    100%
# Arachnodactyly [HP:0001166]                               8/18     44%
# Long fingers [HP:0100807]                                  8/8    100%
# Abnormal finger morphology [HP:0001167]                    8/8    100%
# Abnormal appendicular skeleton morphology [HP:0...         9/9    100%
# Slender finger [HP:0001238]                                8/8    100%
# Aortic aneurysm [HP:0004942]                             11/11    100%
# Vascular dilatation [HP:0002617]                         11/11    100%
# Abnormal blood vessel morphology [HP:0033353]            15/15    100%
# Abnormal morphology of the great vessels [HP:00...       12/12    100%
# Abnormal systemic arterial morphology [HP:0011004]       14/14    100%
# Arterial tortuosity [HP:0005116]                          9/17     53%
# Vascular tortuosity [HP:0004948]                           9/9    100%
# Abnormality of joint mobility [HP:0011729]               12/12    100%
# Abnormal elasticity of skin [HP:0010647]                 10/10    100%
# Subcutaneous hemorrhage [HP:0001933]                       5/5    100%
# Localized skin lesion [HP:0011355]                       10/10    100%
# Abnormal calvaria morphology [HP:0002683]                15/15    100%
# Inguinal hernia [HP:0000023]                              6/14     43%
# Hernia of the abdominal wall [HP:0004299]                  6/6    100%
# Hernia [HP:0100790]                                        6/6    100%
# Abnormal thorax morphology [HP:0000765]                    9/9    100%
#
# What disease was diagnosed                         OMIM:619656          \
#                                                          Count Percent
# Aortic root aneurysm [HP:0002616]                          0/5      0%
# Abnormal sternum morphology [HP:0000766]                  3/13     23%
# Dolichocephaly [HP:0000268]                               3/11     27%
# Hypertelorism [HP:0000316]                                4/14     29%
# Osteoarthritis [HP:0002758]                                2/2    100%
# Scoliosis [HP:0002650]                                    5/12     42%
# Pectus carinatum [HP:0000768]                             0/10      0%
# High palate [HP:0000218]                                  5/15     33%
# Tall stature [HP:0000098]                                 5/10     50%
# Pes planus [HP:0001763]                                   3/10     30%
# Thoracic aortic aneurysm [HP:0012727]                    10/15     67%
# Disproportionate tall stature [HP:0001519]                 0/5      0%
# Dermal translucency [HP:0010648]                           1/5     20%
# Joint hypermobility [HP:0001382]                           1/5     20%
# Pectus excavatum [HP:0000767]                             0/10      0%
# Varicose veins [HP:0002619]                               4/12     33%
# Bifid uvula [HP:0000193]                                  1/14      7%
# Striae distensae [HP:0001065]                              1/5     20%
# Downslanted palpebral fissures [HP:0000494]               2/10     20%
# Bruising susceptibility [HP:0000978]                       5/9     56%
# Abnormal oral cavity morphology [HP:0000163]               6/6    100%
# Abnormal palate morphology [HP:0000174]                    6/6    100%
# Abnormal axial skeleton morphology [HP:0009121]            9/9    100%
# Abnormal midface morphology [HP:0000309]                   1/1    100%
# Abnormal curvature of the vertebral column [HP:...         5/5    100%
# Abnormality of the vertebral column [HP:0000925]           8/8    100%
# Arachnodactyly [HP:0001166]                               6/14     43%
# Long fingers [HP:0100807]                                  6/6    100%
# Abnormal finger morphology [HP:0001167]                    6/6    100%
# Abnormal appendicular skeleton morphology [HP:0...         6/6    100%
# Slender finger [HP:0001238]                                6/6    100%
# Aortic aneurysm [HP:0004942]                             10/10    100%
# Vascular dilatation [HP:0002617]                         11/11    100%
# Abnormal blood vessel morphology [HP:0033353]            15/15    100%
# Abnormal morphology of the great vessels [HP:00...       10/10    100%
# Abnormal systemic arterial morphology [HP:0011004]       14/14    100%
# Arterial tortuosity [HP:0005116]                           1/1    100%
# Vascular tortuosity [HP:0004948]                           1/1    100%
# Abnormality of joint mobility [HP:0011729]                 1/1    100%
# Abnormal elasticity of skin [HP:0010647]                   1/1    100%
# Subcutaneous hemorrhage [HP:0001933]                       5/5    100%
# Localized skin lesion [HP:0011355]                         1/1    100%
# Abnormal calvaria morphology [HP:0002683]                  3/3    100%
# Inguinal hernia [HP:0000023]                              5/11     45%
# Hernia of the abdominal wall [HP:0004299]                  5/5    100%
# Hernia [HP:0100790]                                        7/7    100%
# Abnormal thorax morphology [HP:0000765]                    3/3    100%
#
# What disease was diagnosed                                             \
#                                                    Corrected p values
# Aortic root aneurysm [HP:0002616]                            0.010760
# Abnormal sternum morphology [HP:0000766]                     0.010866
# Dolichocephaly [HP:0000268]                                  0.034928
# Hypertelorism [HP:0000316]                                   0.066583
# Osteoarthritis [HP:0002758]                                  0.120513
# Scoliosis [HP:0002650]                                       0.128188
# Pectus carinatum [HP:0000768]                                0.165202
# High palate [HP:0000218]                                     0.165202
# Tall stature [HP:0000098]                                    0.165202
# Pes planus [HP:0001763]                                      0.165202
# Thoracic aortic aneurysm [HP:0012727]                        0.210156
# Disproportionate tall stature [HP:0001519]                   0.210156
# Dermal translucency [HP:0010648]                             0.431735
# Joint hypermobility [HP:0001382]                             0.476985
# Pectus excavatum [HP:0000767]                                0.749275
# Varicose veins [HP:0002619]                                  0.882047
# Bifid uvula [HP:0000193]                                     0.882047
# Striae distensae [HP:0001065]                                0.882047
# Downslanted palpebral fissures [HP:0000494]                  1.000000
# Bruising susceptibility [HP:0000978]                         1.000000
# Abnormal oral cavity morphology [HP:0000163]                 1.000000
# Abnormal palate morphology [HP:0000174]                      1.000000
# Abnormal axial skeleton morphology [HP:0009121]              1.000000
# Abnormal midface morphology [HP:0000309]                     1.000000
# Abnormal curvature of the vertebral column [HP:...           1.000000
# Abnormality of the vertebral column [HP:0000925]             1.000000
# Arachnodactyly [HP:0001166]                                  1.000000
# Long fingers [HP:0100807]                                    1.000000
# Abnormal finger morphology [HP:0001167]                      1.000000
# Abnormal appendicular skeleton morphology [HP:0...           1.000000
# Slender finger [HP:0001238]                                  1.000000
# Aortic aneurysm [HP:0004942]                                 1.000000
# Vascular dilatation [HP:0002617]                             1.000000
# Abnormal blood vessel morphology [HP:0033353]                1.000000
# Abnormal morphology of the great vessels [HP:00...           1.000000
# Abnormal systemic arterial morphology [HP:0011004]           1.000000
# Arterial tortuosity [HP:0005116]                             1.000000
# Vascular tortuosity [HP:0004948]                             1.000000
# Abnormality of joint mobility [HP:0011729]                   1.000000
# Abnormal elasticity of skin [HP:0010647]                     1.000000
# Subcutaneous hemorrhage [HP:0001933]                         1.000000
# Localized skin lesion [HP:0011355]                           1.000000
# Abnormal calvaria morphology [HP:0002683]                    1.000000
# Inguinal hernia [HP:0000023]                                 1.000000
# Hernia of the abdominal wall [HP:0004299]                    1.000000
# Hernia [HP:0100790]                                          1.000000
# Abnormal thorax morphology [HP:0000765]                      1.000000
#
# What disease was diagnosed
#                                                     p values
# Aortic root aneurysm [HP:0002616]                   0.000229
# Abnormal sternum morphology [HP:0000766]            0.000462
# Dolichocephaly [HP:0000268]                         0.002229
# Hypertelorism [HP:0000316]                          0.005667
# Osteoarthritis [HP:0002758]                         0.012821
# Scoliosis [HP:0002650]                              0.016364
# Pectus carinatum [HP:0000768]                       0.030171
# High palate [HP:0000218]                            0.031952
# Tall stature [HP:0000098]                           0.032508
# Pes planus [HP:0001763]                             0.035149
# Thoracic aortic aneurysm [HP:0012727]               0.052676
# Disproportionate tall stature [HP:0001519]          0.053657
# Dermal translucency [HP:0010648]                    0.119416
# Joint hypermobility [HP:0001382]                    0.142081
# Pectus excavatum [HP:0000767]                       0.239130
# Varicose veins [HP:0002619]                         0.316770
# Bifid uvula [HP:0000193]                            0.335888
# Striae distensae [HP:0001065]                       0.337805
# Downslanted palpebral fissures [HP:0000494]         0.454545
# Bruising susceptibility [HP:0000978]                0.669921
# Abnormal oral cavity morphology [HP:0000163]        1.000000
# Abnormal palate morphology [HP:0000174]             1.000000
# Abnormal axial skeleton morphology [HP:0009121]     1.000000
# Abnormal midface morphology [HP:0000309]            1.000000
# Abnormal curvature of the vertebral column [HP:...  1.000000
# Abnormality of the vertebral column [HP:0000925]    1.000000
# Arachnodactyly [HP:0001166]                         1.000000
# Long fingers [HP:0100807]                           1.000000
# Abnormal finger morphology [HP:0001167]             1.000000
# Abnormal appendicular skeleton morphology [HP:0...  1.000000
# Slender finger [HP:0001238]                         1.000000
# Aortic aneurysm [HP:0004942]                        1.000000
# Vascular dilatation [HP:0002617]                    1.000000
# Abnormal blood vessel morphology [HP:0033353]       1.000000
# Abnormal morphology of the great vessels [HP:00...  1.000000
# Abnormal systemic arterial morphology [HP:0011004]  1.000000
# Arterial tortuosity [HP:0005116]                    1.000000
# Vascular tortuosity [HP:0004948]                    1.000000
# Abnormality of joint mobility [HP:0011729]          1.000000
# Abnormal elasticity of skin [HP:0010647]            1.000000
# Subcutaneous hemorrhage [HP:0001933]                1.000000
# Localized skin lesion [HP:0011355]                  1.000000
# Abnormal calvaria morphology [HP:0002683]           1.000000
# Inguinal hernia [HP:0000023]                        1.000000
# Hernia of the abdominal wall [HP:0004299]           1.000000
# Hernia [HP:0100790]                                 1.000000
# Abnormal thorax morphology [HP:0000765]             1.000000
